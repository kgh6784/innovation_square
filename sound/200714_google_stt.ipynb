# %% [markdown]
# ### 구글이 만든 클라우드 설치

# %%
# !pip install --upgrade google-cloud-speech
# Out:
# Requirement already up-to-date: google-cloud-speech in /usr/local/lib/python3.6/dist-packages (1.3.2)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ### 환경 변수 등록
# `os.environ["환경변수(key value)"]= "주소(json file)"`

# %%
# 여기 실행시켜야함
# import os
# os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="/content/drive/My Drive/Colab Notebooks/google_stt_tts/(json파일이름).json"

# %%
# !env
# Out:
# CUDNN_VERSION=7.6.5.32
# LD_LIBRARY_PATH=/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# CLOUDSDK_PYTHON=python3
# _=/usr/bin/env
# LANG=en_US.UTF-8
# HOSTNAME=c0da3c9af56b
# OLDPWD=/
# CLOUDSDK_CONFIG=/content/.config
# GOOGLE_APPLICATION_CREDENTIALS=/content/drive/My Drive/Colab Notebooks/google_stt_tts/calm-sky-252010-1226b698f8db.json
# NVIDIA_VISIBLE_DEVICES=all
# DATALAB_SETTINGS_OVERRIDES={"kernelManagerProxyPort":6000,"kernelManagerProxyHost":"172.28.0.3","jupyterArgs":["--ip=\"172.28.0.2\""]}
# ENV=/root/.bashrc
# PAGER=cat
# NCCL_VERSION=2.4.8
# TF_FORCE_GPU_ALLOW_GROWTH=true
# JPY_PARENT_PID=23
# NO_GCE_CHECK=True
# PWD=/content
# HOME=/root
# LAST_FORCED_REBUILD=20200709
# CLICOLOR=1
# DEBIAN_FRONTEND=noninteractive
# LIBRARY_PATH=/usr/local/cuda/lib64/stubs
# GCE_METADATA_TIMEOUT=0
# GLIBCPP_FORCE_NEW=1
# TBE_CREDS_ADDR=172.28.0.1:8008
# TERM=xterm-color
# SHELL=/bin/bash
# GCS_READ_CACHE_BLOCK_SIZE_MB=16
# PYTHONWARNINGS=ignore:::pip._internal.cli.base_command
# ...

# %%
import argparse
import io


# [START speech_transcribe_sync]
def transcribe_file(speech_file):
    """Transcribe the given audio file."""
    from google.cloud import speech
    from google.cloud.speech import enums
    from google.cloud.speech import types
    client = speech.SpeechClient()

    # [START speech_python_migration_sync_request]
    # [START speech_python_migration_config]
    with io.open(speech_file, 'rb') as audio_file:
        content = audio_file.read()

    audio = types.RecognitionAudio(content=content)
    config = types.RecognitionConfig(
        encoding=enums.RecognitionConfig.AudioEncoding.LINEAR16,
        # encoding=enums.RecognitionConfig.AudioEncoding.FLAC,
        sample_rate_hertz=16000,
        language_code='ko-KR')
        # language_code='en-US')
    # [END speech_python_migration_config]

    # operation = client.long_running_recognize(config, audio)
    #
    # print('Waiting for operation to complete...')
    # response = operation.result(timeout=90)

    # [START speech_python_migration_sync_response]
    response = client.recognize(config, audio)
    
    # [END speech_python_migration_sync_request]
    # Each result is for a consecutive portion of the audio. Iterate through
    # them to get the transcripts for the entire audio file.
    for result in response.results:
        # The first alternative is the most likely one for this portion.
        print(u'Transcript: {}'.format(result.alternatives[0].transcript))
        print(u'Confidence: {}'.format(result.alternatives[0].confidence))
    # [END speech_python_migration_sync_response]
# [END speech_transcribe_sync]


# [START speech_transcribe_sync_gcs]
def transcribe_gcs(gcs_uri):
    """Transcribes the audio file specified by the gcs_uri."""
    from google.cloud import speech
    from google.cloud.speech import enums
    from google.cloud.speech import types
    client = speech.SpeechClient()

    # [START speech_python_migration_config_gcs]
    audio = types.RecognitionAudio(uri=gcs_uri)
    config = types.RecognitionConfig(
        encoding=enums.RecognitionConfig.AudioEncoding.FLAC,
        sample_rate_hertz=16000,
        language_code='en-US')
    # [END speech_python_migration_config_gcs]

    response = client.recognize(config, audio)
    # Each result is for a consecutive portion of the audio. Iterate through
    # them to get the transcripts for the entire audio file.
    for result in response.results:
        # The first alternative is the most likely one for this portion.
        print(u'Transcript: {}'.format(result.alternatives[0].transcript))
# [END speech_transcribe_sync_gcs]

# %%
import glob
import os
import os.path as pth
from glob import glob
from scipy.io import wavfile
import itertools

# %%
pat = "/content/drive/My Drive/Colab Notebooks/google_stt_tts/wav/"

# %%
filenames = glob(pth.join(pat,"*.wav"))

# %%
filename="/content/drive/My Drive/Colab Notebooks/google_stt_tts/wav/set001003.wav"

# %%
transcribe_file(filenames[2])
# Out:
# Transcript: 그들 가운데서 아무도 소식이 오지 않았다
# Confidence: 0.9236594438552856

# %%
transcribe_file(filename)
# Out:
# Transcript: 그 사람은 정말 이름 그대로 못된 사람입니다
# Confidence: 0.9236594438552856

# %%
len(list(filenames))
# Out:
# 10

# %%
ipd.Audio(filenames[2])
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 한 번에 실행시켜보고 싶은데 실패

# %%
import IPython.display as ipd
for i in range(len(list(filenames))):
  a = ipd.Audio(filenames[i]) # load a local WAV file
  print(a)
# Out:
# <IPython.lib.display.Audio object>
# <IPython.lib.display.Audio object>
# <IPython.lib.display.Audio object>
# <IPython.lib.display.Audio object>
# <IPython.lib.display.Audio object>
# <IPython.lib.display.Audio object>
# <IPython.lib.display.Audio object>
# <IPython.lib.display.Audio object>
# <IPython.lib.display.Audio object>
# <IPython.lib.display.Audio object>
